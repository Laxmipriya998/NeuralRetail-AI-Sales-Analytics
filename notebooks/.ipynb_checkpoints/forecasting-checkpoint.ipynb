# %% [markdown]
# # Objective

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
df = pd.read_csv("../data/processed/cleaned_retail_data.csv")

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.linear_model import LinearRegression

plt.style.use("ggplot")

pd.set_option("display.max_columns", None)

# %% [markdown]
# # Dataset Overview

# %%
df = pd.read_csv(
    "../data/processed/cleaned_retail_data.csv"
)

# %%
df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  TotalSales  Year  \
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.4  2009
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0  2009
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0  2009
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.8  2009
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.0  2009
#
#    Month  Day  Hour  DayOfWeek  DayName  IsWeekend  Season  InventoryLevel  \
# ...

# %%
df["InvoiceDate"] = pd.to_datetime(
    df["InvoiceDate"]
)

# %%
daily_sales = df.groupby(
    df["InvoiceDate"].dt.date
)["TotalSales"].sum().reset_index()

# %%
daily_sales.columns = [
    "Date",
    "Sales"
]

# %%
daily_sales.head()
# Out:
#          Date     Sales
# 0  2009-12-01  43894.87
# 1  2009-12-02  52762.06
# 2  2009-12-03  67413.62
# 3  2009-12-04  33913.81
# 4  2009-12-05   9803.05

# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/cleaned_retail_data.csv"
)

# %% [markdown]
# # Feature Engineering

# %%
df = df.sort_values("InvoiceDate")

df["Lag_1"] = df["TotalSales"].shift(1)
df["Lag_7"] = df["TotalSales"].shift(7)
df["Lag_14"] = df["TotalSales"].shift(14)

df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  TotalSales  Year  \
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.4  2009
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0  2009
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0  2009
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.8  2009
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.0  2009
#
#    Month  Day  Hour  DayOfWeek  DayName  IsWeekend  Season  InventoryLevel  \
# ...

# %%
df["Rolling_Mean_7"] = df["TotalSales"].rolling(7).mean()
df["Rolling_Std_7"] = df["TotalSales"].rolling(7).std()

# %%
df = df.dropna()
df.head()
# Out:
#     Invoice StockCode                    Description  Quantity  \
# 14   489436     21754       HOME BUILDING BLOCK WORD         3
# 15   489436     84879  ASSORTED COLOUR BIRD ORNAMENT        16
# 16   489436     22119     PEACE WOODEN BLOCK LETTERS         3
# 17   489436     22142   CHRISTMAS CRAFT WHITE FAIRY         12
# 18   489436     22296      HEART IVORY TRELLIS LARGE        12
#
#             InvoiceDate  Price  Customer ID         Country  TotalSales  Year  \
# 14  2009-12-01 09:06:00   5.95      13078.0  United Kingdom       17.85  2009
# 15  2009-12-01 09:06:00   1.69      13078.0  United Kingdom       27.04  2009
# 16  2009-12-01 09:06:00   6.95      13078.0  United Kingdom       20.85  2009
# 17  2009-12-01 09:06:00   1.45      13078.0  United Kingdom       17.40  2009
# 18  2009-12-01 09:06:00   1.65      13078.0  United Kingdom       19.80  2009
#
#     Month  Day  Hour  DayOfWeek  DayName  IsWeekend  Season  InventoryLevel  \
# ...

# %%
df.to_csv("../data/processed/final_features.csv", index=False)

# %%
plt.figure(figsize=(15,5))

plt.plot(
    daily_sales["Date"],
    daily_sales["Sales"]
)

plt.title("Daily Sales Trend")

plt.xlabel("Date")

plt.ylabel("Sales")

plt.show()

# %%
daily_sales["TimeIndex"] = np.arange(
    len(daily_sales)
)

# %%
X = daily_sales[["TimeIndex"]]

y = daily_sales["Sales"]

# %% [markdown]
# # Model Training

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
daily_sales["PredictedSales"] = model.predict(X)

# %%
import joblib

joblib.dump(
    model,
    "../models/forecast_model.pkl"
)

print("Forecast model saved successfully")
# Out:
# Forecast model saved successfully

# %%
plt.figure(figsize=(15,5))

plt.plot(
    daily_sales["Date"],
    daily_sales["Sales"],
    label="Actual Sales"
)

plt.plot(
    daily_sales["Date"],
    daily_sales["PredictedSales"],
    label="Predicted Sales"
)

plt.legend()

plt.title("Sales Forecast")

plt.show()

# %%
future_days = pd.DataFrame({

    "TimeIndex": np.arange(
        len(daily_sales),
        len(daily_sales) + 30
    )

})

future_predictions = model.predict(
    future_days
)

# %%
future_predictions
# Out:
# array([36725.54220872, 36777.92402932, 36830.30584991, 36882.68767051,
#        36935.0694911 , 36987.4513117 , 37039.83313229, 37092.21495289,
#        37144.59677348, 37196.97859408, 37249.36041467, 37301.74223527,
#        37354.12405586, 37406.50587646, 37458.88769705, 37511.26951765,
#        37563.65133824, 37616.03315884, 37668.41497943, 37720.79680002,
#        37773.17862062, 37825.56044121, 37877.94226181, 37930.3240824 ,
#        37982.705903  , 38035.08772359, 38087.46954419, 38139.85136478,
#        38192.23318538, 38244.61500597])

# %% [markdown]
# # Conclusion

# %%
daily_sales.to_csv(
    "../data/processed/forecast_data.csv",
    index=False
)

# %%
print(df.columns)
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'TotalSales', 'Year', 'Month', 'Day',
#        'Hour', 'DayOfWeek', 'DayName', 'IsWeekend', 'Season', 'InventoryLevel',
#        'CustomerTotalSales', 'HolidaySeason', 'Lag_1', 'Lag_7', 'Lag_14',
#        'Rolling_Mean_7', 'Rolling_Std_7'],
#       dtype='str')

# %%
print(daily_sales.columns)
# Out:
# Index(['Date', 'Sales', 'TimeIndex', 'PredictedSales'], dtype='str')
