# %% [markdown]
# # Objective

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
df = pd.read_csv("../data/processed/cleaned_retail_data.csv")

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

plt.style.use("ggplot")

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv(
    "../data/processed/cleaned_retail_data.csv"
)

# %% [markdown]
# # Dataset Overview

# %%
df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  TotalSales  Year  \
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.4  2009
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0  2009
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0  2009
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.8  2009
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.0  2009
#
#    Month  Day  Hour  DayOfWeek  DayName  IsWeekend  Season  InventoryLevel  \
# ...

# %% [markdown]
# how much each product sells

# %% [markdown]
# # Inventory Analysis

# %%
inventory_df = df.groupby(
    "Description"
).agg({

    "Quantity": "sum",

    "TotalSales": "sum"

}).reset_index()

# %%
inventory_df.columns = [

    "Product",

    "TotalQuantitySold",

    "TotalRevenue"
]

# %%
np.random.seed(42)

inventory_df["CurrentStock"] = np.random.randint(

    20,
    500,

    size=len(inventory_df)
)

# %% [markdown]
# # Inventory Optimization

# %%
inventory_df["ReorderLevel"] = 50

# %%
inventory_df["LowStockAlert"] = np.where(

    inventory_df["CurrentStock"]
    < inventory_df["ReorderLevel"],

    "YES",

    "NO"
)

# %%
inventory_df.head()
# Out:
#                                Product  TotalQuantitySold  TotalRevenue  \
# 0    DOORMAT UNION JACK GUNS AND ROSES                167       1071.25
# 1             3 STRIPEY MICE FELTCRAFT                662       1241.10
# 2        4 PURPLE FLOCK DINNER CANDLES                200        265.20
# 3                      ANIMAL STICKERS                385         80.85
# 4          BLACK PIRATE TREASURE CHEST                 45         74.25
#
#    CurrentStock  ReorderLevel LowStockAlert
# 0           122            50            NO
# 1           455            50            NO
# 2           368            50            NO
# 3           290            50            NO
# 4           126            50            NO

# %%
low_stock = inventory_df[
    inventory_df["LowStockAlert"] == "YES"
]

low_stock.head()
# Out:
#                               Product  TotalQuantitySold  TotalRevenue  \
# 7    CAMPHOR WOOD PORTOBELLO MUSHROOM                 43         53.75
# 33          12 EGG HOUSE PAINTED WOOD                364       3751.40
# 57             200 BENDY SKULL STRAWS                601        682.85
# 64         3 HOOK HANGER MAGIC GARDEN               1056       1854.00
# 85         36 PENCILS TUBE RED SPOTTY               3225       3882.29
#
#     CurrentStock  ReorderLevel LowStockAlert
# 7             40            50           YES
# 33            41            50           YES
# 57            40            50           YES
# 64            33            50           YES
# 85            21            50           YES

# %%
top_products = inventory_df.sort_values(

    by="TotalRevenue",
    ascending=False

).head(10)

# %%
plt.figure(figsize=(12,5))

plt.bar(

    top_products["Product"],
    top_products["CurrentStock"]

)

plt.xticks(rotation=90)

plt.title("Top Product Inventory")

plt.show()

# %% [markdown]
# # Conclusion

# %%
inventory_df.to_csv(

    "../data/processed/inventory_data.csv",

    index=False
)

# %%
print(inventory_df.columns)
# Out:
# Index(['Product', 'TotalQuantitySold', 'TotalRevenue', 'CurrentStock',
#        'ReorderLevel', 'LowStockAlert'],
#       dtype='str')
